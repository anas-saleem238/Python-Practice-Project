# %%
# 4.1

friends = ["Asham", "Hashir", "Hammas"]

invite1 = friends[0]
print("Assalamualaikum " + friends[0] + ", You're invited to our dinner.")

invite2 = friends[1]
print("Assalamualaikum " + friends[1] + ", You're invited to our dinner.")

invite3 = friends[2]
print("Assalamualaikum " + friends[2] + ", You're invited to our dinner.")
# Out:
# Assalamualaikum Asham, You're invited to our dinner.
# Assalamualaikum Hashir, You're invited to our dinner.
# Assalamualaikum Hammas, You're invited to our dinner.

# %%
#4.2

friends = ["Asham", "Hashir", "Hammas"]

invite1 = friends[0]
print("Assalamualaikum " + friends[0] + ", You're invited to our dinner.")

invite2 = friends[1]
print("Assalamualaikum " + friends[1] + ", You're invited to our dinner.")

invite3 = friends[2]
print("Assalamualaikum " + friends[2] + ", You're invited to our dinner.")

invite4 = friends[1]
print("\nSorry " + friends[1] + ", You can't make it to our dinner.")

friends[1] = "Taimoor"

invite1 = friends[0]
print("\nAssalamualaikum " + friends[0] + ", You're invited to our dinner.")

invite2 = friends[1]
print("Assalamualaikum " + friends[1] + ", You're invited to our dinner.")

invite3 = friends[2]
print("Assalamualaikum " + friends[2] + ", You're invited to our dinner.")
# Out:
# Assalamualaikum Asham, You're invited to our dinner.
# Assalamualaikum Hashir, You're invited to our dinner.
# Assalamualaikum Hammas, You're invited to our dinner.
#
# Sorry Hashir, You can't make it to our dinner.
#
# Assalamualaikum Asham, You're invited to our dinner.
# Assalamualaikum Taimoor, You're invited to our dinner.
# Assalamualaikum Hammas, You're invited to our dinner.

# %%
#4.3

friends = ["Asham", "Hashir", "Hammas"]

invite1 = friends[0]
print("Assalamualaikum " + friends[0] + ", You're invited to our dinner.")

invite2 = friends[1]
print("Assalamualaikum " + friends[1] + ", You're invited to our dinner.")

invite3 = friends[2]
print("Assalamualaikum " + friends[2] + ", You're invited to our dinner.")

invite4 = friends[1]
print("\nSorry " + friends[1] + ", You can't make it to our dinner.")

friends[1] = "Taimoor"

invite1 = friends[0]
print("\nAssalamualaikum " + friends[0] + ", You're invited to our dinner.")

invite2 = friends[1]
print("Assalamualaikum " + friends[1] + ", You're invited to our dinner.")

invite3 = friends[2]
print("Assalamualaikum " + friends[2] + ", You're invited to our dinner.")

print("\nHurrah! We found a bigger dinner table.")

friends.insert(0, "Atir")
friends.insert(2, "Ahmer")
friends.append("Ali")

invite1 = friends[0]
print("\nAssalamualaikum " + friends[0] + ", You're invited to our dinner.")

invite2 = friends[1]
print("Assalamualaikum " + friends[1] + ", You're invited to our dinner.")

invite3 = friends[2]
print("Assalamualaikum " + friends[2] + ", You're invited to our dinner.")

invite4 = friends[3]
print("Assalamualaikum " + friends[3] + ", You're invited to our dinner.")

invite5 = friends[4]
print("Assalamualaikum " + friends[4] + ", You're invited to our dinner.")

invite6 = friends[5]
print("Assalamualaikum " + friends[5] + ", You're invited to our dinner.")
# Out:
# Assalamualaikum Asham, You're invited to our dinner.
# Assalamualaikum Hashir, You're invited to our dinner.
# Assalamualaikum Hammas, You're invited to our dinner.
#
# Sorry Hashir, You can't make it to our dinner.
#
# Assalamualaikum Asham, You're invited to our dinner.
# Assalamualaikum Taimoor, You're invited to our dinner.
# Assalamualaikum Hammas, You're invited to our dinner.
#
# Hurrah! We found a bigger dinner table.
#
# Assalamualaikum Atir, You're invited to our dinner.
# Assalamualaikum Asham, You're invited to our dinner.
# Assalamualaikum Ahmer, You're invited to our dinner.
# Assalamualaikum Taimoor, You're invited to our dinner.
# Assalamualaikum Hammas, You're invited to our dinner.
# Assalamualaikum Ali, You're invited to our dinner.

# %%
#4.4

friends = ["Asham", "Hashir", "Hammas"]

invite1 = friends[0]
print("Assalamualaikum " + friends[0] + ", You're invited to our dinner.")

invite2 = friends[1]
print("Assalamualaikum " + friends[1] + ", You're invited to our dinner.")

invite3 = friends[2]
print("Assalamualaikum " + friends[2] + ", You're invited to our dinner.")

invite4 = friends[1]
print("\nSorry " + friends[1] + ", You can't make it to our dinner.")

friends[1] = "Taimoor"

invite1 = friends[0]
print("\nAssalamualaikum " + friends[0] + ", You're invited to our dinner.")

invite2 = friends[1]
print("Assalamualaikum " + friends[1] + ", You're invited to our dinner.")

invite3 = friends[2]
print("Assalamualaikum " + friends[2] + ", You're invited to our dinner.")

print("\nHurrah! We found a bigger dinner table.")

friends.insert(0, "Atir")
friends.insert(2, "Ahmer")
friends.append("Ali")

invite1 = friends[0]
print("\nAssalamualaikum " + friends[0] + ", You're invited to our dinner.")

invite2 = friends[1]
print("Assalamualaikum " + friends[1] + ", You're invited to our dinner.")

invite3 = friends[2]
print("Assalamualaikum " + friends[2] + ", You're invited to our dinner.")

invite4 = friends[3]
print("Assalamualaikum " + friends[3] + ", You're invited to our dinner.")

invite5 = friends[4]
print("Assalamualaikum " + friends[4] + ", You're invited to our dinner.")

invite6 = friends[5]
print("Assalamualaikum " + friends[5] + ", You're invited to our dinner.")

# Now table will not be arrived in time, I can invite only 2 people !

print("\nSorry, There are only 2 seats available")

invite5 = friends[4]
print("\nAssalamualaikum " + invite5 + ", You're invited to our dinner.")

invite6 = friends[5]
print("Assalamualaikum " + invite6 + ", You're invited to our dinner.")


invite1 = friends.pop(3)
print("Sorry " + invite1 + ", You can't make it to dinner.")

invite2 = friends.pop(2)
print("Sorry " + invite2 + ", You can't make it to dinner.")

invite3 = friends.pop(1)
print("Sorry " + invite3 + ", You can't make it to dinner.")

invite4 = friends.pop(0)
print("Sorry " + invite4 + ", You can't make it to dinner.")
# Out:
# Assalamualaikum Asham, You're invited to our dinner.
# Assalamualaikum Hashir, You're invited to our dinner.
# Assalamualaikum Hammas, You're invited to our dinner.
#
# Sorry Hashir, You can't make it to our dinner.
#
# Assalamualaikum Asham, You're invited to our dinner.
# Assalamualaikum Taimoor, You're invited to our dinner.
# Assalamualaikum Hammas, You're invited to our dinner.
#
# Hurrah! We found a bigger dinner table.
#
# Assalamualaikum Atir, You're invited to our dinner.
# Assalamualaikum Asham, You're invited to our dinner.
# Assalamualaikum Ahmer, You're invited to our dinner.
# Assalamualaikum Taimoor, You're invited to our dinner.
# Assalamualaikum Hammas, You're invited to our dinner.
# Assalamualaikum Ali, You're invited to our dinner.
#
# Sorry, There are only 2 seats available
#
# Assalamualaikum Hammas, You're invited to our dinner.
# Assalamualaikum Ali, You're invited to our dinner.
# Sorry Taimoor, You can't make it to dinner.
# ...
